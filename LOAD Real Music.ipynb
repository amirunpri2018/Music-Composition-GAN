# %%
from keras.models import Sequential, Model, load_model

import numpy as np

from random import randrange

from mido import MidiFile, MidiTrack, Message

import mido

import NoteBins
# Out:
# Using TensorFlow backend.

# %%
x_train = np.load(r'C:\Users\Vee\Desktop\python\GAN\Music GAN\answers.npy',allow_pickle=True)

# %%
#sample
jamie = x_train[randrange(len(x_train))]
for x in range(16):
    jamie[x][0] = abs(jamie[x][0] * 11)
print(jamie)
# Out:
# [[ 5.]
#  [11.]
#  [ 7.]
#  [ 7.]
#  [ 4.]
#  [ 7.]
#  [ 7.]
#  [ 4.]
#  [ 5.]
#  [11.]
#  [ 2.]
#  [ 4.]
#  [ 2.]
#  [10.]
#  [ 4.]
#  [ 7.]]

# %%
jamie = [[71],[64],[71],[66],[71],[78],[63],[75],[73],[64],[66],[71],[78],[63],[71],[78]]

# %%
timing = np.load(r'C:\Users\Vee\Desktop\python\csp.npy',allow_pickle=True)
count = 0
mid = MidiFile()
track = MidiTrack()
mid.tracks.append(track)
track2 = MidiTrack()
mid.tracks.append(track2)
track3 = MidiTrack()
mid.tracks.append(track3)
track4 = MidiTrack()
mid.tracks.append(track4)
octave = 12 * 6
t = randrange(len(timing))

track.append(Message('program_change', program=2,time=0))
track2.append(Message('program_change', program=2, time=0))
track3.append(Message('program_change', program=2,time=0))
track4.append(Message('program_change', program=2, time=0))
    
for i in range(2):
    track2.append(Message('note_on', note= 68, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 68, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 64, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 64, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 59, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=59, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 69, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 69, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 66, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 66, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 62, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=62, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 73, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 73, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 68, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 68, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 64, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=64, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 69, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 69, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 66, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 66, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 62, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=62, velocity=randrange(70,80), time=1920))
for x in range(2):
    count = 0
    for i in range(16):
        if(i == 0):
            track.append(Message('note_on', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=0))
        else:
            track.append(Message('note_on', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=20))
        track.append(Message('note_off', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=timing[t].get(str(i))))
        count = count + 1
mid.save('major.mid')

# %%
timing = np.load(r'C:\Users\Vee\Desktop\python\csp.npy',allow_pickle=True)
count = 0
mid = MidiFile()
track = MidiTrack()
mid.tracks.append(track)
track2 = MidiTrack()
mid.tracks.append(track2)
track3 = MidiTrack()
mid.tracks.append(track3)
track4 = MidiTrack()
mid.tracks.append(track4)
octave = 12 * 5
t = randrange(len(timing))

track.append(Message('program_change', program=2,time=0))
track2.append(Message('program_change', program=2, time=0))
track3.append(Message('program_change', program=2,time=0))
track4.append(Message('program_change', program=2, time=0))
    
for i in range(2):
    track2.append(Message('note_on', note= 52, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 52, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 48, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 48, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 43, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=43, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 52, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 52, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 48, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 48, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 45, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=45, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 54, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 54, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 50, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 50, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 43, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=43, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 55, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 55, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 40, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 40, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 47, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=47, velocity=randrange(70,80), time=1920))
for x in range(2):
    count = 0
    for i in range(16):
        if(i == 0):
            track.append(Message('note_on', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=0))
        else:
            track.append(Message('note_on', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=20))
        track.append(Message('note_off', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=timing[t].get(str(i))))
        count = count + 1
mid.save('major2.mid')

# %%
timing = np.load(r'C:\Users\Vee\Desktop\python\csp.npy',allow_pickle=True)
count = 0
mid = MidiFile()
track = MidiTrack()
mid.tracks.append(track)
track2 = MidiTrack()
mid.tracks.append(track2)
track3 = MidiTrack()
mid.tracks.append(track3)
track4 = MidiTrack()
mid.tracks.append(track4)
octave = 12 * 6
t = randrange(len(timing))

track.append(Message('program_change', program=2,time=0))
track2.append(Message('program_change', program=2, time=0))
track3.append(Message('program_change', program=2,time=0))
track4.append(Message('program_change', program=2, time=0))
    
for i in range(2):
    track2.append(Message('note_on', note= 63, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 63, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 60, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 60, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 55, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=55, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 63, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 63, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 58, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 58, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 55, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=55 , velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 65, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 65, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 60, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 60, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 56, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=56, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 67, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 67, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 62, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 62, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 59, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=59, velocity=randrange(70,80), time=1920))
for x in range(2):
    count = 0
    for i in range(16):
        if(i == 0):
            track.append(Message('note_on', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=0))
        else:
            track.append(Message('note_on', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=20))
        track.append(Message('note_off', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=timing[t].get(str(i))))
        count = count + 1
mid.save('minor.mid')

# %%
timing = np.load(r'C:\Users\Vee\Desktop\python\csp.npy',allow_pickle=True)
count = 0
mid = MidiFile()
track = MidiTrack()
mid.tracks.append(track)
track2 = MidiTrack()
mid.tracks.append(track2)
track3 = MidiTrack()
mid.tracks.append(track3)
track4 = MidiTrack()
mid.tracks.append(track4)
octave = 12 * 6
t = randrange(len(timing))

track.append(Message('program_change', program=2,time=0))
track2.append(Message('program_change', program=2, time=0))
track3.append(Message('program_change', program=2,time=0))
track4.append(Message('program_change', program=2, time=0))
    
for i in range(2):
    track2.append(Message('note_on', note= 61, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 61, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 58, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 58, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 53, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=53, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 65, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 65, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 60, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 60, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 57, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=57, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 65, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 65, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 60, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 60, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 56, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=56, velocity=randrange(70,80), time=1920))

    track2.append(Message('note_on', note= 63, velocity=randrange(70,80), time=0))
    track2.append(Message('note_off', note= 63, velocity=randrange(70,80), time=1920))
    track3.append(Message('note_on', note= 60, velocity=randrange(70,80), time=0))
    track3.append(Message('note_off', note= 60, velocity=randrange(70,80), time=1920))
    track4.append(Message('note_on', note= 56, velocity=randrange(70,80), time=0))
    track4.append(Message('note_off', note=56, velocity=randrange(70,80), time=1920))
for x in range(2):
    count = 0
    for i in range(16):
        if(i == 0):
            track.append(Message('note_on', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=0))
        else:
            track.append(Message('note_on', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=20))
        track.append(Message('note_off', note= octave + NoteBins.note_reg(int(jamie[i][0])), velocity=randrange(90,110), time=timing[t].get(str(i))))
        count = count + 1
mid.save('minor2.mid')
